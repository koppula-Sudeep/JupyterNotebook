# %% [markdown]
# <a href="https://colab.research.google.com/github/koppula-Sudeep/JupyterNotebook/blob/main/interview%20questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1 = [1,2,4,8]
list2 = [1,3,5,9]
list1.extend(list2)
list1.sort()
print(list1)
# Out:
# [1, 1, 2, 3, 4, 5, 8, 9]

# %%
list1 = [1,2,4,8,10]
list2 = [1,3,5,9]
i = 0
j = 0
li = []
while i < len(list1) and j < len(list2):
    if list1[i]<list2[j]:
        li.append(list1[i])
        i += 1
    elif list1[i]>list2[j]:
        li.append(list2[j])
        j += 1
    else:
        li.append((list1[i],list2[j]))
        i += 1
        j += 1
# Append remaining elements from list1
while i < len(list1):
    li.append(list1[i])
    i += 1

# Append remaining elements from list2
while j < len(list2):
    li.append(list2[j])
    j += 1
print(li)
# Out:
# [(1, 1), 2, 3, 4, 5, 8, 9, 10]

# %%
st='Hello world I Love Python'
dict = {}
count=0
vowels = ['a','e','i','o','u','A','E','I','O','U']
k = st.split()
for i in k:
    dict[i] = i
for key, val in dict.items():
    count = 0
    for j in val:
        if j in vowels:
            count += 1
    dict[key] = count
print(dict)
# Out:
# {'Hello': 2, 'world': 1, 'I': 1, 'Love': 2, 'Python': 1}

# %%
st = 'Hello world I Love Python'
vowels = ['a', 'e', 'i', 'o', 'u', 'A', 'E', 'I', 'O', 'U']
dict = {}

# Split the string into words
words = st.split()

# Count the vowels in each word and populate the dictionary
for i in words:
    count = sum(1 for j in i if j in vowels)
    dict[i] = count
print(dict)
# Out:
# {'Hello': 2, 'world': 1, 'I': 1, 'Love': 2, 'Python': 1}

# %%
def squares(a):
    for i in range(a):
        if a == i**2:
            return True
    return False
print(squares(101))
# print(squares(36))

# %%
class test:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def display(self):
        return f"The name is {self.name} and {self.age}"

obj = test("sudeep", 26)
print(obj.display())

# %%
def keywords(dictionary,s):
    k = ''
    for i in dictionary:
        k += i
        if k == s:
            return True
    return False

dictionary = ["data", "camp", "cam", "lack"]
s = "datacamp"
print(keywords(dictionary,s))
# Out:
# True

# %%
class decor:
    def __init__(self,func):
        self.func = func

    def __call__(self,s):
        s=s.upper()
        return self.func(s)

@decor
def str(s):
    return s

print(str("simple"))
# Out:
# SIMPLE

# %%
def decor(func):
    def inner(s):
        s = s.upper()
        return func(s)
    return inner

@decor
def str(s):
    return s

print(str("simple"))
# Out:
# SIMPLE

# %%
# Output : [1,2,3,4,%,6,7,8,9,&,11,12,13,14,%,16,17,18,19,&]
num = 20
li = []
for i in range(1,num+1):
    if i/5 in [1,3,5,7]:
        li.append('%')
    elif i/10 in [1,2,3,4,5,6,7]:
        li.append('&')
    else:
        li.append(i)
print(li)
# Out:
# [1, 2, 3, 4, '%', 6, 7, 8, 9, '&', 11, 12, 13, 14, '%', 16, 17, 18, 19, '&']

# %%
#  Print repeat numbers from list
li =  [1,2,3,4,5,1,2,3]
dict = {}
new_li = []
for i in li:
    if i in dict:
        dict[i] += 1
    else:
        dict[i] = 1
for key, val in dict.items():
    if val>1:
        new_li.append(key)
print(new_li)
# Out:
# [1, 2, 3]

# %%
# Reverse a string and keep vowels in the original place
# Eg: CANDIDATE  ->  TADDINACE
strs = 'CANDIDATE'
# Convert string to list to perform swap operations
strs_list = list(strs)

left = 0
right = len(strs_list) - 1
vowels = ['a','e','i','o','u','A','E','I','O','U']

while left <= right:
    if strs_list[left] not in vowels and strs_list[right] not in vowels:
        # Swap the elements
        strs_list[left], strs_list[right] = strs_list[right], strs_list[left]
        left += 1
        right -= 1
    elif strs_list[left] not in vowels and strs_list[right] in vowels:
        right -= 1
    elif strs_list[left] in vowels and strs_list[right] not in vowels:
        left += 1
    else:
        left += 1
        right -= 1

print(result)
# Out:
# TADDINACE

# %%
'''''
1
2 9
3 8 10
4 7 11 14
5 6 12 13 15
'''''
# Out:
# 1
# 2 6
# 3 7 10
# 4 8 11 13
# 5 9 12 14 15

# %%
strg = '(a+b)*(c-d)'
s = ''
li = ['(',')']
for i in range(len(strg)):
    if strg[i] in li:
        s += strg[i]
print(s)
while '()' in s:
    s = s.replace('()','')
if len(s) == 0:
    print(True)
else:
    print(False)
# Out:
# ()()
# True

# %%
# Integer Reversing
def int_palidrome(original_number):
    s = original_number
    reverse_order = 0
    while s>0:
        remainder = s%10
        reverse_order = reverse_order*10 + remainder
        s = s//10
    return reverse_order

original_number = 1234
print(int_palidrome(original_number))
original_number = 121
print(int_palidrome(original_number))
# Out:
# 4321
# 121

# %%
s = 1234
reverse_order = 0
while s>0:
    remainder = s%10
    reverse_order = reverse_order*10 + remainder
    s = s//10
print(reverse_order)
# Out:
# 4321

# %%
messages = [
    {"order_id": "A1", "status": "NEW"},
    {"order_id": "A2", "status": "REJECTED"},
    {"order_id": "A3", "status": "REJECTED"}
]

rejected = [m["order_id"] for m in messages if m["status"]=="REJECTED"]
print(rejected)
# Out:
# ['A2', 'A3']

# %%
def is_valid_parentheses(s):
    stack = []
    pairs = {')':'(', '}':'{', ']':'['}

    for ch in s:
        if ch in '({[':
            stack.append(ch)
        else:
            if not stack or stack[-1] != pairs[ch]:
                return False
            stack.pop()

    return len(stack) == 0


# Example
print(is_valid_parentheses("()[]{}"))   # True
print(is_valid_parentheses("(]"))       # False
# Out:
# True
# False
